# %%
import re
import json
import time
import dataclasses
from typing import Optional

import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import *
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC

# %%
USER = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"

REVIEW_LINK = "https://www.google.com/maps/search/spain+hotels/@31.774513,-15.9297508,5z/data=!3m1!4b1?hl=en&entry=ttu"

# %%
@dataclasses.dataclass
class Review:
    review_id: str
    author_link: str
    author_title: str
    author_id: str
    author_image: str
    review_text: str
    owner_answer: str
    owner_answer_timestamp: str
    owner_answer_timestamp_datetime_utc: str
    review_link: str
    review_rating: str
    review_timestamp: str
    review_datetime_utc: str
    review_likes: str
    review_img_url: Optional[list] = dataclasses.field(default_factory=list)

@dataclasses.dataclass
class Scores:
    one_star: str
    two_stars: str
    three_stars: str
    four_stars: str
    five_stars: str
    
@dataclasses.dataclass
class Place:
    name: str
    google_id: str
    rating: str
    reviews_total: str
    location_link: str
    reviews_link: Optional[str] = None
    reviews_id: Optional[str] = None
    reviews_per_score: Scores = None
    reviews: list[Review] = dataclasses.field(default_factory=list)

# %%
options = webdriver.ChromeOptions()

options.add_argument("--disable-infobars")

options.add_argument('--no-sandbox')

options.add_argument('--start-maximized')

options.add_argument('--ignore-gpu-blocklist')

options.add_argument('--single-process')

options.add_argument('--disable-dev-shm-usage')

# options.add_argument("--headless=new")

options.add_argument(f"user-agent={USER}")

options.add_argument("--incognito")

options.add_argument('--disable-blink-features=AutomationControlled')

options.add_experimental_option('useAutomationExtension', False)

options.add_experimental_option("excludeSwitches", ["enable-automation"])

options.add_argument("--log-level=3")

options.add_argument('--disable-extensions')

options.add_argument('--lang=en-GB')

options.set_capability('pageLoadStrategy', 'none')

chrome_service = Service()
# chrome_service.creation_flags = CREATE_NO_WINDOW

while True:
    try:
        browser = webdriver.Chrome(service=chrome_service, 
                                        options=options)

        browser.command_executor._commands["SEND_COMMAND"] = (
            "POST", "/session/$sessionId/chromium/send_command"
        )
        
        break

    except:pass

# %%
browser.get(REVIEW_LINK)

# %%
feed = browser.find_element(By.CSS_SELECTOR, "div[role='feed']")

# %%
previous_len, trials = 0, 0

while True:
    businesses = feed.find_elements(By.CSS_SELECTOR,
                                    'div[class="TFQHme "]')
    
    if len(businesses) == previous_len:
        if trials == 4:
            break

        trials += 1

        time.sleep(10)

    previous_len = len(businesses)
    
    feed.send_keys(Keys.END)

    time.sleep(5)

# %%
businesses_cont = browser.find_element(By.CSS_SELECTOR,
                                "div[role='feed']")

businesses = businesses_cont.find_elements(By.XPATH, "./*")

start_found = False

companies: list[WebElement] = []

for element in businesses:
    if start_found and not element.get_attribute("class"):
        companies.append(element)

    if element.get_attribute("role") == "presentation":
        start_found = True

print(len(companies))
# Out:
# 6

# %%
re.search(r"(.+?)\n(\d+\.?\d?)\s*\(([\d,]+)", 
                companies[0].text,
                flags=re.I|re.DOTALL).group(3)
# Out:
# '2,956'

# %%
# ActionChains(browser).move_to_element_with_offset(companies[2], 0, 50).perform()

# desired_pos = 100

# browser.execute_script("window.scrollBy(0, arguments[0]);", desired_pos)

element = companies[2]

# browser.execute_script("return arguments[0].scrollIntoView(0, document.documentElement.scrollHeight);", element

element.location_once_scrolled_into_view
# Out:
# {'x': 72, 'y': 211}

# %%
feed.send_keys(Keys.PAGE_DOWN)

# %%
places: list[Place] = []

for company in companies:
    details = re.search(r"(.+?)\n(\d+\.?\d?)\s*\(([\d,]+)", 
                company.text,
                flags=re.I|re.DOTALL)

    if not details: continue

    name = details.group(1)

    rating = details.group(2)

    reviews = details.group(3)

    for link in company.find_elements(By.TAG_NAME, "a"):
        if re.search(rf'{name}', 
                    link.get_attribute("aria-label"),
                    flags=re.I):
            place_link_tag = link

            break

    location_link = place_link_tag.get_attribute("href")

    jslog: str = place_link_tag.get_attribute("jslog")

    google_id_re = re.search(r"metadata:(.+)", jslog, re.I)

    google_id = google_id_re.group(1)

    place = Place(name=name, 
                  google_id=google_id,
                  rating=rating,
                  reviews_total=reviews,
                  location_link=location_link)
    
    places.append(place)

# %%
browser.execute_script('''window.open("{}","_blank");'''.format(places[0].location_link))

# %%
browser.switch_to.window(browser.window_handles[0])

# %%
browser.title
# Out:
# 'spain hotels - Google Maps'

# %%
places[-1]
# Out:
# Place(name='Palacio de los Duques Gran Meliá - The Leading Hotels of the World', google_id='WyIwYWhVS0V3aXYtc24xbV91QkF4WDlTUEVESGVTS0M4OFE4QmNJdFFJb0FBIixudWxsLDNd', rating='4.7', reviews_total='1,934', location_link='https://www.google.com/maps/place/Palacio+de+los+Duques+Gran+Meli%C3%A1+-+The+Leading+Hotels+of+the+World/data=!4m10!3m9!1s0xd42287bbb349661:0x97dbe6a71867fcc6!5m2!4m1!1i2!8m2!3d40.4197035!4d-3.7096772!16s%2Fg%2F1tr9pqw6!19sChIJYZY0u3soQg0RxvxnGKfm25c?authuser=0&hl=en&rclk=1', reviews_link=None, reviews_id=None, reviews_per_score=None, reviews=[])

# %%
def locate(selector: str,
           method: By,
           driver: Optional[WebElement]=None,
           multiple: Optional[bool]=False,
           breakout: Optional[bool]=True) -> WebElement|list[WebElement]:
        if driver is None:
            driver = browser
        
        trials = 0

        while True:
            try:
                if multiple:
                    return driver.find_elements(method, selector)
                else:
                    return driver.find_element(method, selector)
            
            except Exception as e: 
                if trials == 3 and breakout:
                    return
                
                trials += 1

                time.sleep(10)
                print(selector)

mappings = {"1": "one_star",
            "2": "two_stars",
            "3": "three_stars",
            "4": "four_stars",
            "5": "five_stars"}

# %%
def get_review(review_element: WebElement, container: WebElement) -> Review:
    # ActionChains(browser).move_to_element(review_element).perform()
    review_element.location_once_scrolled_into_view
    
    review_id = review_element.get_attribute("data-review-id")

    review_text_tag = locate(driver=review_element,
                             selector=f"div[id='{review_id}']",
                             method=By.CSS_SELECTOR)
    
    try:
        see_more = review_text_tag.find_element(By.CSS_SELECTOR, 
                                                'button[aria-label="See more"]')
        
        see_more.click()

        time.sleep(1)

    except:pass

    review_text = review_text_tag.text
    
    author_re = re.search(r"([\w\s'\-]+)\n.*?(\d+)\s*reviews?.*?\n(\d{1,2}/\d{1,2})\n([\w\s]+?ago)", 
                          review_element.text,
                          flags=re.DOTALL|re.I)

    if not author_re: 
        print(review_element.text)
        return
    
    name = author_re.group(1)
    # author_reviews_num = author_re.group(2)
    review_rating = author_re.group(3)
    review_posted = author_re.group(4)

    buttons: list[WebElement] = locate(
        method=By.CSS_SELECTOR, 
        driver=review_element,
        multiple=True,
        selector=f'button[data-review-id="{review_id}"]'
    )

    review_images = []
    
    for button in buttons:
        aria_label = button.get_attribute("aria-label")

        button_text = aria_label if aria_label else ""
        
        if re.search(r"photo\s+of", button_text, re.I):
            author_link: str = button.get_attribute("data-href")

            image = locate(method=By.TAG_NAME, 
                           selector="img",
                           driver=button)

            author_image_link = image.get_attribute("src")

            author_id_re = re.search(r"contrib/(.+)/review", author_link)

            author_id = author_id_re.group(1)
        
        if re.search(r"Share", button_text, re.I):
            print(button_text)

            while True:
                try:
                    button.location_once_scrolled_into_view
                    # ActionChains(browser).move_to_element(button).perform()

                    # window_h = browser.execute_script('return window.innerHeight')
                    # window_y = browser.execute_script('return window.pageYOffset')
                    # current_y = (window_h / 2) + window_y

                    # container.send_keys(Keys.PAGE_DOWN)

                    button.click()

                    time.sleep(2)

                    input_tag = locate(
                        method=By.CSS_SELECTOR,
                        selector='input[jsaction="pane.copyLink.clickInput"]')

                    review_link = input_tag.get_attribute("value")

                    locate(selector='button[aria-label="Close"]',
                        method=By.CSS_SELECTOR).click()
                    
                    time.sleep(2)

                    break

                except: pass
            
        title = button.get_attribute("title")

        title = title if title else ""

        likes_re = re.search(r"(\d*)\s*like", title, re.I)

        if likes_re:
            likes = likes_re.group(1)

            likes = likes if likes.strip() else "0"
        
        photo_index = button.get_attribute("data-photo-index")

        if photo_index:
            style: str = button.get_attribute("style")

            image_re = re.search(r"(http.+)&quot;", style)

            if image_re:
                review_images.append(image_re.group(1))

    response_re = re.search(r"Response\s+from\s+the\s+owner\s*([\w\s]+ago)\s(.+)",
                            review_element.text,
                            flags=re.I|re.DOTALL)

    if response_re:
        owner_answer_timestamp = response_re.group(1)
        owner_answer = response_re.group(2)
    else:
        owner_answer_timestamp = ""
        owner_answer = ""
    
    review = Review(review_id=review_id,
                author_link=author_link,
                author_title=name,
                author_id=author_id,
                author_image=author_image_link,
                review_text=review_text,
                owner_answer=owner_answer,
                owner_answer_timestamp=owner_answer_timestamp,
                owner_answer_timestamp_datetime_utc=None,
                review_link=review_link,
                review_rating=review_rating,
                review_timestamp=review_posted,
                review_datetime_utc=None,
                review_likes=likes,
                review_img_url=review_images)
    
    return review

# %%
def load_more_reviews(reviews_container: WebElement) -> None:
    reviews_container.send_keys(Keys.END)
    time.sleep(5)

# %%
for place in places[:3]:
    browser.get(place.location_link)

    time.sleep(3)

    for _ in range(3):
        try:
            score_tags: list[WebElement] = locate(
                selector="tr[role='img']", 
                method=By.CSS_SELECTOR, 
                multiple=True
            )

            scores = {}

            for tag in score_tags:
                score_text: str = tag.get_attribute("aria-label")

                scores_re = re.search(r"(\d)\s*\w+,\s*([\d,]+)", score_text)

                scores[mappings[scores_re.group(1)]] = scores_re.group(2)
            
            place.reviews_per_score = Scores(**scores)
        except:
            time.sleep(5)

    buttons: list[WebElement] = locate(
        selector='button[role="tab"]',
        method=By.CSS_SELECTOR,
        multiple=True
    )

    for button in buttons:
        aria_label = button.get_attribute("aria-label")
        
        if not aria_label: continue

        if re.search(r"reviews", aria_label, re.I):
            button.click()

            time.sleep(2)
            
            place.reviews_link = browser.current_url

            reviews_id_re = re.search(r"data=(.+)\?", place.reviews_link)

            place.reviews_id = reviews_id_re.group(1)

            refine_reviews = locate(
                selector='div[aria-label="Refine reviews"]',
                method=By.CSS_SELECTOR,
            )

            reviews_container = locate(selector="..",
                                       method=By.XPATH,
                                       driver=refine_reviews)
            
            len_reviews, trials = 0, 0
            
            while True:
                load_more_reviews(reviews_container)

                review_tags = locate(
                    method=By.CSS_SELECTOR,
                    selector='div[class="jftiEf fontBodyMedium "]',
                    multiple=True)

                if len(review_tags) == len_reviews \
                    or len(review_tags) >= 200:
                    if trials == 4 or len(review_tags) >= 200:
                        break

                    trials += 1

                    time.sleep(10)

                    continue

                len_reviews = len(review_tags)

                trials = 0

            
            for review_tag in review_tags[:200]:
                review = get_review(review_tag, reviews_container)

                if review is not None:
                    place.reviews.append(review)
            
            break
# Out:
# input[jsaction="pane.copyLink.clickInput"]
# input[jsaction="pane.copyLink.clickInput"]
# Share Shared Account's review.
# Share Ruth Coulson's review.
# Share Dan Kit's review.
# Share JHon Cas's review.
# Share Andre's review.
# Share Sarah Harding's review.
# Share Neal Smith's review.
# Share FWM's review.
# Share Matthew Hall's review.
# Share Patrick Farrell's review.
# Share Rory Gleeson's review.
# Share Christof Byers's review.
# Share Christian Andersson's review.
# Share John James's review.
# Share Champagne's review.
# Share Natalie 44118's review.
# Share Vernon Beacham's review.
# Share Sue Bonsor's review.
# Share Insert Text Here with Daro's review.
# Share Stefan Beutler's review.
# Share Chantal van der Giessen's review.
# Share Bernadette Keegan's review.
# Share Ryan Leishman's review.
# Share Claire Davies's review.
# Share Svein-Magne Tunli's review.
# Share rachel kirk's review.
# Share Ian Johnson's review.
# Share Steve Crawford's review.
# Share Roy Grew's review.
# Share Ken H's review.
# Share Matti Räty's review.
# Share CJ's review.
# Share Arthur Moffatt's review.
# Share Nigel Tiltman's review.
# Share Colin Eyley's review.
# Share RICHARD BUSWELL's review.
# Share Lars Söderström's review.
# Share Sharron Williams's review.
# Share Andrew Neish's review.
# Share peter hymer's review.
# Share Ron Hefford's review.
# Share Angelica E's review.
# Share Bill McColl's review.
# Share John O'Neill's review.
# Share Vera Vera's review.
# input[jsaction="pane.copyLink.clickInput"]
# Share Michele Lee's review.
# Share Julie Kelley's review.
# Share Geraldine Smythe's review.
# Share Anna Voltchenkova's review.
# Share Chris Rogers's review.
# Share Anna M's review.
# Share Martin locke's review.
# Share Joanna Ahmed's review.
# Share Andy Walther's review.
# Alba
# 1/10
# a month ago on
# Priceline
# Share Wojciech Szymkiewicz's review.
# Share myra whalan's review.
# Share Henrik Tufte Schrøder's review.
# Share Anand Sahasrabudhe's review.
# Share Giles Robinson's review.
# Share Aymeric Douyère's review.
# Share Olivia Cummings's review.
# Share Jake P's review.
# Share Stefano Aldegheri's review.
# Share Trupti Kavia's review.
# Share Vapor Haze's review.
# Share Aleksandrs Gusevs's review.
# Share S F's review.
# Share Rutger Truyers's review.
# Share Noel siba's review.
# Share craig blease's review.
# Share Zuzu Sweet's review.
# Share Iriaxi Torres's review.
# Share Darragh's review.
# Share Nataša Marković's review.
# Share Gary Baitson's review.
# Share Andrei Beșuțiu's review.
# Share Rashin Siamaki Pour's review.
# Share Chris Prestel's review.
# Share Amrish Majithia's review.
# Share Gerd Hoffmann's review.
# Share Adrian Matei's review.
# Share Kristina Druin's review.
# Share Shomo Shabas's review.
# Share Jeff Gale's review.
# Share Sinéad's review.
# Share Shane Tews's review.
# Share Maria Delanzo's review.
# Share Wendy Beer's review.
# Share Terry Green's review.
# Share Andrea Bernard's review.
# Share Mantas's review.
# Share Michalis Tsagaris's review.

# %%
place = places[0]

for review_tag in review_tags[:200]:
    review = get_review(review_tag)

    if review is not None:
        place.reviews.append(review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/towett/Documents/Upwork/review-scraper/scraper.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/home/towett/Documents/Upwork/review-scraper/scraper.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> place = places[0]
#       <a href='vscode-notebook-cell:/home/towett/Documents/Upwork/review-scraper/scraper.ipynb#X61sZmlsZQ%3D%3D?line=2'>3</a> for review_tag in review_tags[:200]:
#       <a href='vscode-notebook-cell:/home/towett/Documents/Upwork/review-scraper/scraper.ipynb#X61sZmlsZQ%3D%3D?line=3'>4</a>     review = get_review(review_tag)
#
# NameError: name 'places' is not defined

# %%
dataclasses.asdict(place)
# Out:
# {'name': 'Hotel Riu Papayas',
#  'google_id': 'WyIwYWhVS0V3aWdfdGlVanZtQkF4VkRUNlFFSFZWY0MyQVE4QmNJOFJRb0FBIl0=',
#  'rating': '4.5',
#  'reviews_total': '3,383',
#  'location_link': 'https://www.google.com/maps/place/Hotel+Riu+Papayas/data=!4m10!3m9!1s0xc3f62bde181f7a9:0xdadf70ce344183aa!5m2!4m1!1i2!8m2!3d27.763355!4d-15.572008!16s%2Fg%2F1tfsd2qt!19sChIJqfeB4b1iPwwRqoNBNM5w39o?authuser=0&hl=en&rclk=1',
#  'reviews_link': 'https://www.google.com/maps/place/Hotel+Riu+Papayas/@27.7633552,-15.5720078,17z/data=!3m1!5s0xc3f62bde871caeb:0x84dd1809654d84d!4m11!3m10!1s0xc3f629454909933:0xdadf70ce344183aa!5m2!4m1!1i2!8m2!3d27.7633552!4d-15.5720078!9m1!1b1!16s%2Fg%2F1tfsd2qt?authuser=0&hl=en&entry=ttu',
#  'reviews_id': '!3m1!5s0xc3f62bde871caeb:0x84dd1809654d84d!4m11!3m10!1s0xc3f629454909933:0xdadf70ce344183aa!5m2!4m1!1i2!8m2!3d27.7633552!4d-15.5720078!9m1!1b1!16s%2Fg%2F1tfsd2qt',
#  'reviews_per_score': {'one_star': '66',
#   'two_stars': '48',
#   'three_stars': '195',
#   'four_stars': '871',
#   'five_stars': '2,203'},
#  'reviews': [{'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURSNjR2ME9nEAE',
#    'author_link': 'https://www.google.com/maps/contrib/111479741889045205427/reviews?hl=en',
#    'author_title': 'Chelsea White',
#    'author_id': '111479741889045205427',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocL_n9dThyokIq4e2xWMLNhyFD1IjXLUvdjbycCX5Pad=w36-h36-p-rp-mo-br100',
#    'review_text': 'If you were a smoking couple this would be perfect for you! As a family with 2 young children the smoking was way too much, they even do a kids Congo line through the smoking area. The main seating area for the shows is all smoking with a … More',
#    'owner_answer': 'Dear Chelsea White,\n\nThank you very much for taking time to tell us about your stay and staying with us.\n\nIt is very disappointing to read people who smoke made your stay less pleasant, please allow us to highlight that Riu follows the local regulations regarding this matter.\n\nNevertheless, we are really sorry and your review will be forwarded to the management department. \n\nKind Regards, \n\nHotel Riu Papayas\nOnline Reputation Manager',
#    'owner_answer_timestamp': '5 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/CxG7SoKwk6exDrfw6',
#    'review_rating': '3/5',
#    'review_timestamp': '5 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '4',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURSNjR2ME9nEAE',
#    'author_link': 'https://www.google.com/maps/contrib/111479741889045205427/reviews?hl=en',
#    'author_title': 'Chelsea White',
#    'author_id': '111479741889045205427',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocL_n9dThyokIq4e2xWMLNhyFD1IjXLUvdjbycCX5Pad=w36-h36-p-rp-mo-br100',
#    'review_text': 'If you were a smoking couple this would be perfect for you! As a family with 2 young children the smoking was way too much, they even do a kids Congo line through the smoking area. The main seating area for the shows is all smoking with a … More',
#    'owner_answer': 'Dear Chelsea White,\n\nThank you very much for taking time to tell us about your stay and staying with us.\n\nIt is very disappointing to read people who smoke made your stay less pleasant, please allow us to highlight that Riu follows the local regulations regarding this matter.\n\nNevertheless, we are really sorry and your review will be forwarded to the management department. \n\nKind Regards, \n\nHotel Riu Papayas\nOnline Reputation Manager',
#    'owner_answer_timestamp': '5 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/sxmPYjPeQkNesmNs8',
#    'review_rating': '3/5',
#    'review_timestamp': '5 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '4',
#    'review_img_url': []}]}

# %%
results = []

for place in places:
    results.append(dataclasses.asdict(place))

# %%
results[0]
# Out:
# {'name': 'Radisson Blu Resort & Spa, Gran Canaria Mogan',
#  'google_id': 'WyIwYWhVS0V3alMyLXFReGZtQkF4WERWcVFFSFlGNEFyOFE4QmNJeEJVb0FBIl0=',
#    'owner_answer_timestamp': 'a month ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/qTUcFgvRyks72ENYA',
#    'review_rating': '5/5',
#    'review_timestamp': 'a month ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUM1OHIyLW9BRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/102956945398801007607/reviews?hl=en',
#    'author_title': 'Andy R',
#    'author_id': '102956945398801007607',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocL7ol8xxwuAGp0WGN-to7yUMFQTye93JDEYXK7n3t1Y=w36-h36-p-rp-mo-ba5-br100',
#    'review_text': "A great place to stay within a 10 minutes walk to the harbour. Good standard of rooms, some with pool access which I'd recommend. The sunbeds are quite uncomfortable with a support bar which intrudes when relaxing. It would be good to have a pool bar service so you can order from your sunbed.",
#    'owner_answer': "Thank you for taking the time to share your feedback about your recent stay with us. \n\nWe're delighted to hear that you found our location convenient, with just a 10-minute walk to the harbor. We take pride in offering our guests comfortable and well-appointed rooms, and we're pleased to hear you enjoyed your stay in our pool access rooms.\n\nYour note about the sunbeds is valuable, and we'll look into ways to improve their comfort, addressing the issue of the support bar. Your comfort is important to us, and we'll strive to make your next visit even more relaxing.\n\nRegarding pool bar service, your suggestion is well-received.\n\nThank you for choosing to stay with us, and we hope to have the opportunity to welcome you back in the future, where we aim to make your experience even more enjoyable.",
#    'owner_answer_timestamp': '2 days ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/brkQo8MFeanBMrLF6',
#    'review_rating': '4/5',
#    'review_timestamp': '3 days ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNweW8ydWN3EAE',
#    'author_link': 'https://www.google.com/maps/contrib/116832601179259709436/reviews?hl=en',
#    'author_title': 'warren atkinson',
#    'author_id': '116832601179259709436',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjV40s7L9IQB2s7viUZRmET8tLibq2nZzGGW6H_se06BQIk=w36-h36-p-rp-mo-br100',
#    'review_text': '7 night stay- found the hotel to be great for the majority. Child friendly hotel without being over the top with kids. The pull out bed could be much better and is a pull out spring mattress. Breakfast had plenty of options and was good. Staff were friendly and attentive with the exception of the bald headed life guard. Removed towels off the sun beds while I took my daughter to the toilet as weren’t allowed to reserve sunbeds (we’d been gone 2 minutes.) When I asked him why he couldn’t speak a word of English to answer my questions but could speak perfects English with everyone else.',
#    'owner_answer': 'We really appreciate your feedback about your stay at our hotel. We are glad to hear that overall your experience was excellent and that you enjoyed our services and facilities.\nHowever, we are sorry to hear that there were some aspects that did not meet your expectations. We will take into consideration your comments regarding the folding bed and mattress to discuss possible improvements in that area to ensure greater comfort for our guests.\nWith regards to the incident with the lifeguard, we apologise for any inconvenience this may have caused and will pass your comments on to the responsible department to follow up.\nFinally, we are glad to hear that you enjoyed the breakfast and that you were very complimentary about the exceptional treatment you received from our team members. \nWe hope that you will give us another opportunity to host you in the future and that you will enjoy an even more satisfying experience.',
#    'owner_answer_timestamp': '2 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/gz7nGLMhmRBVy5Fn7',
#    'review_rating': '4/5',
#    'review_timestamp': '2 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURwal9PN213RRAB',
#    'author_link': 'https://www.google.com/maps/contrib/101768694906254191157/reviews?hl=en',
#    'author_title': 'bups ss',
#    'author_id': '101768694906254191157',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocK-eGh899ucZMIIGrGWccqV_DRJ4SPYwj3QtMYzIXPS=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': "Just come back here after a weeks stay.  Its a fantastic hotel in a good location in a quiet location.   Good friendly staff and service.   Great for kids and adults.\n\nIt's not exactly 5 star hotel. But good solid 4 star.   It's a place I'd definitely return to in near future and highly recommend.",
#    'owner_answer': "Thank you for taking the time to share your valuable feedback with us. We're thrilled to hear that you had a fantastic stay and found our hotel to be in a quiet yet convenient location with friendly staff and great service.\nRegarding your feedback on the pull-out bed, we apologize for any discomfort you experienced, and we'll certainly look into improving this aspect for a better sleep experience.\nWe look forward to welcoming you back for another enjoyable stay.",
#    'owner_answer_timestamp': 'a month ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/AyxcnXFvcznriYCV7',
#    'review_rating': '4/5',
#    'review_timestamp': 'a month ago',
#    'review_datetime_utc': None,
#    'review_likes': '1',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUM1dE1qOVVREAE',
#    'author_link': 'https://www.google.com/maps/contrib/114612794407890558050/reviews?hl=en',
#    'author_title': 'Sharon Grundill',
#    'author_id': '114612794407890558050',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocKfCJYoWgSJ2JL_8m_yzNyw3oo_WocKbp8AaX07eNSZ=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': 'The most comfortable bed I have  ever slept on in a hotel  ever.  And the pillows are like you sink into a  marshmallow. The pool areas are great 3 in all one for the little ones, a lively one and a quiet one. The room was huge with a bath and a shower separate.  And the balcony  with tables and chairs. And 2 sunlounger very  comfortable too. For me, the walk to the harbour  was hard .but found a taxi rank for less than 5 euros, and we asked  hotel reception to ring a taxi .took less than  5 mins to come . But for people who are OK to walk  good location to walk down to the harbour  for the restaurants,  shops would take  15 minutes or less. Would highly recommend this hotel.. There is a spar on sight. I have a massage booked  for later today . There is a gym on site and football, tennis,volleyball  pichers.and a rock-climbing wall plenty to do for the children and adults to do',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURwcDZ2eklREAE',
#    'author_link': 'https://www.google.com/maps/contrib/100668851684492122858/reviews?hl=en',
#    'author_title': 'Luca Hemsley',
#    'author_id': '100668851684492122858',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjWozo3rUzTQQJqACLIVBoih1blOXBrFfriA8xkF18wsgj8=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': "One of my favorite holidays! This hotel is located in Mogan, the harbour, with restaurants and shops, is only a 15 minute walk away from the hotel and the nearest supermarket and small shopping centre which contains shops and a few restaurants is only a 5 minute walk away from the hotel reception exit. The hotel itself is well run, luxurious and has a great layout. The 2 pools and a very shallow pool, allow adults to have some quiet time on the 1st floor pool, while children can play with balls, be loud and mess around in the kids pool on floor 0 (which is slightly salty) but you don't notice it. Floor 0 also is where the entertainment takes place and also where the restaurants, bar, gym and spa are located. On floor 0 there is a smaller restaurant for lunch which is next to the quiet pool, there is also a volleyball court, tennis court, paddle court and a football court which is open 24/7 to have a kick about with your friends or to play a organized game by the hotel at 10am on Tuesdays, Thursdays and Sundays! Floors 2 and 3 only have rooms, but floor 4 has a sun deck and yoga deck. The food at the breakfast buffet is nice and runs until 11am. The hotel staff are very nice and helpful and the room service is quick and anything you need at the hotel, they will most likely have it, such as a power adapter for UK plugs, clothes drier, extra pillows etc. Overall I had a great experience at the hotel and definitely would stay at a raddison blu hotel again!",
#    'owner_answer': "It sounds like you had an amazing experience at the hotel! Your detailed description of its location, facilities, and services truly captures the essence of what makes it special. It's great to hear that the hotel's layout, pools, and various amenities provided such a comfortable stay.\n The availability of sports facilities like the volleyball, tennis, paddle, and football courts, along with the organized games, is definitely a plus for our guests who enjoy staying active during their holidays.\nWe thank you also for the positive comments about the breakfast buffet and the helpfulness of the hotel staff.\n Thanks for sharing your experience in such detail! We hope to have the opportunity to welcome you again!",
#    'owner_answer_timestamp': 'a month ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/idFpMPtwg2FZFvLz8',
#    'review_rating': '5/5',
#    'review_timestamp': 'a month ago',
#    'review_datetime_utc': None,
#    'review_likes': '1',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNaMThxNElREAE',
#    'author_link': 'https://www.google.com/maps/contrib/101294799841905619668/reviews?hl=en',
#    'author_title': 'Lianne Whitehead',
#    'author_id': '101294799841905619668',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocKJ5lbs3MPz7lKBfE3tD5rG5GOvDnV2S3Dzqj1AzZA=w36-h36-p-rp-mo-br100',
#    'owner_answer_timestamp': '2 weeks ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/JSimPrdinkEGAvBm6',
#    'review_rating': '4/5',
#    'review_timestamp': '3 weeks ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURKaDdyWnhBRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/102017948556675020125/reviews?hl=en',
#    'author_title': 'Kjeld van Heijningen',
#    'author_id': '102017948556675020125',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocKpBXvSpErZTzltQmmnInjGuOcL5dDPG4BsgnkICz1A=w36-h36-p-rp-mo-br100',
#    'review_text': 'First time in this hotel, in short not a 5 star hotel for sure. Bad quality towels, no service in the pool area. Rooms are more then outdated and shower equipment as well as chrome all is not maintained properly. Cleaning is terrible and hairs and others they just leave on the floor. Water in the pool gets really warm this period and is to small for the amount of people in the hotel.\n\nSoccer field and tennis is perfect\nBreakfast is reasonable ok\n\nRadisson app does not work, you can ask things 20 x and it just does not come ..',
#    'owner_answer': 'Thank you very much for choosing us and for taking the time to write this review. \nWe are sorry to hear that you had some inconveniences during your stay. We thank you for your comments and apologise. We will forward your comments to the relevant departments as it is thanks to our guests that we are able to constantly improve. We kindly ask you to always contact our reception team during your stay so that we can assist you at all times and meet your needs. \nWe hope to have the opportunity to welcome you again in the future and to offer you a memorable stay.',
#    'owner_answer_timestamp': '2 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/E6RZxgaXp4zmSg1y8',
#    'review_rating': '2/5',
#    'review_timestamp': '2 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURwN05uYmt3RRAB',
#    'author_link': 'https://www.google.com/maps/contrib/101456910471557362096/reviews?hl=en',
#    'author_title': 'S Croall',
#    'author_id': '101456910471557362096',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocICW79pVsnxtxRP0HJsjs7XzZyMPobhg8CxrjI5leZL=w36-h36-p-rp-mo-ba5-br100',
#    'review_text': 'Popular with families this is a great resort hotel for guaranteed sun and heat. The pool was 32 C in August and there are 4 pools a quiet chlorine one, a small kids salt water one and the large main salt water family pool.\n\nServal organised fun games a day (eg water polo, pool aerobics etc), bingo and a show each evening.\n\nYou will no doubt spend a lot of time looking at rocks of the nearby cliffs. It is in a valley so day are slightly shorter than some place.\n\nFood is good and the breakfast buffet is plentiful and varied with the usual resort pancake and egg station.\n\nNo inflatables in the pools.\n\nThe location is about a 400m walk from the sea / beach. This is fine but the walk shows some of the resort of Morgan seems to have been abandoned in its development.\n\nThe restaurants at the beach and the new town(the bit that looks like Venice.. allegedly..yeh right. It has a couple of bridges) are not any cheaper than the hotel restaurants.',
#    'owner_answer_timestamp': '3 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/UL7Q5cNKB265bG9B7',
#    'review_rating': '5/5',
#    'review_timestamp': '3 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURad2VYSy13RRAB',
#    'author_link': 'https://www.google.com/maps/contrib/103211083335634471228/reviews?hl=en',
#    'author_title': 'Carl Tyler',
#    'author_id': '103211083335634471228',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocJzxF5JoLo5Y3mw_FTfMnXDoX2dYkFli10Q4fmcWBJS=w36-h36-p-rp-mo-ba3-br100',
#    'review_text': 'Amazing hotel and facilities\nStaff were great, food was great.\nThe only downside is its quite a way to the beach.',
#    'owner_answer': "Thank you for your wonderful feedback! We're thrilled to hear that you enjoyed your stay at our hotel and that you found our staff and food to be great.\n\nRegarding the distance to the beach, we apologize for any inconvenience you may have experienced. In fact, our hotel is only a short 15-minute walk from the beach, which allows you to enjoy the best of both worlds - the tranquility of our facilities and the beauty of the beach just a stone's throw away. We hope to welcome you back soon!",
#    'owner_answer_timestamp': 'a week ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/4zY45MJxW5ov7hoJ8',
#    'review_rating': '5/5',
#    'review_timestamp': 'a week ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUR4dWRYdkdREAE',
#    'author_link': 'https://www.google.com/maps/contrib/100196018214686354947/reviews?hl=en',
#    'author_title': 'Tom Bladon',
#    'author_id': '100196018214686354947',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjXKXjZSV8E5DmSgOllMeiR7e5qEi7gCmVsfSpakmL7ABjpk=w36-h36-p-rp-mo-ba2-br100',
#    'review_text': 'Enjoyed our 9 night stay at the Radisson Blu in Mogan. We stayed in the top section of the hotel around the quiet pool. Bed was super comfy, a great balcony with comfy loungers, and a great selection for breakfast (Would advise going a little earlier to avoid the rush at peak times). Staff were very welcoming and helpful. My only slight issue was with the cleaning of the rooms - Our dirty cups/glasses were not replaced everyday and our towels disappeared over the stay (not sure why they were taken but not replaced). It still gets 5* from us though!',
#    'owner_answer': 'First of all, thank you for sharing us your fabulous opinion about your recent stay in Radisson Blu Resort & Spa Gran Canaria, Mogán.\n\nWe are extremely pleased that you liked our hotel and that you enjoyed your stay with us. We appreciate your kind words regarding the rooms, beds, breakfast and team members; we will share your comments with the whole team as guests like you make us very proud to work at the hotel and give us motivation to keep going and improving.\nThis time, we do regret to read that we could not satisfy your expectations in every moment, especially in terms of cleanliness. We will consider your feedback and we will pass all the information to the corresponding departments in order to take action to improve our services.\nWe hope that you will continue to give us the pleasure of hosting you.',
#    'owner_answer_timestamp': '4 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/xkqy61aKr21nWXnv7',
#    'review_rating': '5/5',
#    'review_timestamp': '4 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURKM01pZ013EAE',
#    'author_link': 'https://www.google.com/maps/contrib/112272549218438951842/reviews?hl=en',
#    'author_title': 'Pat Laing',
#    'author_id': '112272549218438951842',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjV9iKmsy4ToOBlGo_-iGTuI5u6GiWTony6nV1wdMCAVpGZO=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': 'Lovely modern resort hotel . We had half board. The food was excellent. Great pool areas with jacuzzis. Not far from Puerto Mogan. Entertainment every night. Beds are so comfortable. Aircon, safe and fridge in all rooms. Kettle in Superior rooms. Staff always kind and helpful.',
#    'owner_answer': "Thank you for your wonderful review of our resort hotel! We're thrilled to hear that you enjoyed your stay and that our modern facilities, including the great pool areas and jacuzzis, met your expectations. It's also great to know that you found the food to be excellent and that you appreciated the comfort of our beds. We strive to provide a range of amenities, including air conditioning, safes, and fridges, to ensure our guests have a comfortable and enjoyable experience. We're glad our staff was kind and helpful throughout your stay. We hope to welcome you back in the future for another memorable stay!",
#    'owner_answer_timestamp': '3 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/NxyhsqrfoGCd36UD7',
#    'review_rating': '5/5',
#    'review_timestamp': '3 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNKajRyNWlRRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/109415704536102160964/reviews?hl=en',
#    'author_title': 'PAUL PENGE',
#    'author_id': '109415704536102160964',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocJlh0dSGS_Mhgkwk-Lz9ttZenBhFjA-q0Cv2-zuus8y=w36-h36-p-rp-mo-br100',
#    'review_text': 'A sublime hotel. My premier room was spacious and tastefully decorated. I highly recommend paying extra for dinner, since there is a vast array of dishes and the value exceeds local restaurants.',
#    'owner_answer': "Thank you for your great review ! We're glad you enjoyed your spacious and tastefully decorated premier room and our dinner options. We appreciate your feedback and hope to welcome you back in the future.",
#    'owner_answer_timestamp': '3 months ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/Mv37Uw2x1TzkpbNu8',
#    'review_rating': '5/5',
#    'review_timestamp': '3 months ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURwaDhPN1J3EAE',
#    'author_link': 'https://www.google.com/maps/contrib/118222905427534471550/reviews?hl=en',
#    'author_title': 'Richard Choi',
#    'author_id': '118222905427534471550',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjVTBST6sSUBEHfFEujWxad-GhUM0RFnE7TekcgMrYzwlP-e=w36-h36-p-rp-mo-ba3-br100',
#    'review_text': 'Great resort spend 7 nights with family at this Radisson blu, the staff were exceptional and the kids loved it.  1 large family pool, a quiet pool and a kids pool which were not too busy.',
#    'owner_answer': "Thank you for your positive feedback! We're delighted to know that you and your family had a fantastic  stay at our resort. Our team takes pride in delivering exceptional service, and we're thrilled that the amenities, including the different pool options, added to your family's enjoyment. We truly appreciate your feedback and hope to have the pleasure of welcoming you back for another memorable experience in the future!",
#    'owner_answer_timestamp': 'a month ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/AVV2FFo9xF2Fj6C8A',
#    'review_rating': '5/5',
#    'review_timestamp': 'a month ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNKNFlqWW5RRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/117367073400029529627/reviews?hl=en',
#    'author_title': 'Dorte Roskvist',
#    'author_id': '117367073400029529627',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjWbuTFVycTKlUe2-DBEZGq0F66AdQ8KE91HBPACmVuRxg=w36-h36-p-rp-mo-br100',
#    'review_text': 'We allready knew the hotel, the fantastic rooms, facilities and the nice staff. This is our third holiday at Radisson Blu Resort and Spa, but for the first time we had Asian dinner buffet in the Larder Restaurant and both the food and the rosè was amazing👏 for all 6 of us from age of 16 to 92🥳',
# ...
#    'owner_answer': 'Thank you for staying with us and for sharing your impressions, Bob. We are delighted that you enjoyed our hotel´s environment. We are sorry to hear about the incident with the strawberries and we apologize for the inconvenience. Our F&B team will follow up in order to prevent future discontents.\nWe hope to have another chance to welcome you and provide you with a truly memorable holiday experience. Kind regards',
#    'owner_answer_timestamp': 'a year ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/rrXU7qfozoppgBYRA',
#    'review_rating': '3/5',
#    'review_timestamp': 'a year ago',
#    'review_datetime_utc': None,
#    'review_likes': '1',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURRd3BxU1ZBEAE',
#    'author_link': 'https://www.google.com/maps/contrib/102220329056842995559/reviews?hl=en',
#    'author_title': 'Ivy Mcninch',
#    'author_id': '102220329056842995559',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocIu5qypfK-ggA0TUjTvi9IC4-065pJZOw8VA6nQatk=w36-h36-p-rp-mo-br100',
#    'review_text': "Wonderful, modern hotel in a great location. We had a beautiful mini suite with mountain and pool views. The beds and pillows were heavenly - real down pillows. The main room and bathroom were spacious and beautifly appointed. The double terrace was huge with a table and chair combo and 2 large loung beds and there was still loads of room!\nOur room, common areas, gym, pools and restaurant were sparkling clean. They might of had a problem in the past but wasn't an issue when we were here.\nThe breakfast was very good with the most options I've ever come across. All the usual breakfast items but also whole salmon ( 2 types), pate, meatballs, and a whole Scandi section.  They had fresh OJ in pitchers, but if that wasn't fresh enough for your taste they had a juice press.\nALL the staff were exceptional! Polite, friendly, helpful, professional and ready to smile and share a joke. Actually, I felt the whole (beautiful) town was one of the most friendly of places. I would love to go back and have no reservations about recommending this hotel!",
#    'owner_answer': 'Dear Ivy, thank you for taking the time to share such a positive review on Radisson Blu Resort & Spa Gran Canaria Mogan on Google. We are so pleased to read about your fantastic holiday experience with us in the lovely fishing village Puerto de Mogan. Great to read you fully enjoyed our modern and well-appointed rooms, spacious comune and pool areas, plentiful super breakfast buffet and our friendly and helpful staff. We look forward to your next stay! Warm regards',
#    'owner_answer_timestamp': '5 years ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/G9sPC8SAXwjSrVr17',
#    'review_rating': '5/5',
#    'review_timestamp': '5 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUR5aDhIYU1BEAE',
#    'author_link': 'https://www.google.com/maps/contrib/109787618493554691451/reviews?hl=en',
#    'author_title': 'Jonas T',
#    'author_id': '109787618493554691451',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjXp0j20L-4msO9W4Cg-8yohkZhcIKt64WgwaIACRgkmvw=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': "A clean and we'll maintained 5 star hotel 10 min walk from the beach. Three heated pools, kids area and massage pools. Great breakfast and rooms. Breakfast, pool bars and room service were great.",
#    'owner_answer': 'Thank you for sharing your experience. We are delighted to know you enjoyed everythign in our hotel. We hope to welcome back soon.',
#    'owner_answer_timestamp': '2 years ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/TM8Qx5egGErsEdVL9',
#    'review_rating': '5/5',
#    'review_timestamp': '2 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNnbUl2VHRRRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/115435256934129555578/reviews?hl=en',
#    'author_title': 'Manohar Chhapolia',
#    'author_id': '115435256934129555578',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjXsefhKEEMrVT5Mp26wJbq2H5lAl9g_BcSQU4ncc1GwYWxe=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': "I had booked this resort to celebrate my wife birthday in Gran Canaria.\n\nGood things first.\n\n1. Big facility\n2. They have lots of event happening most of the time.\n3 multiple nice restaurant and bars.\n\nNeed improvement\n1. They have very weired parking place. If your room is on other side of resort then even worst for you.\n\n2. We were 2 families and booked 2 rooms. They gave us both rooms pretty far and when asked ... They said ... You did not request both room together. ( I have never request such a thing )\n\n3. I had booked this restaurant to celebrate my wife's birthday. I bought 1 cake from outside and handed over to their restaurant and order one cake in resort restaurant itself. We wanted it to be special and restaurant/resort lost both the cakes. In response they just said they will not charge us for the cake (which they never delivered)\n\n4. They found the cake next day and left us in our room. By the time we came to room (11 pm ). It was spoiler and we had to throw it.\n\nMay be my expectation was too high with a 5 star resort and I am very disappointed.",
#    'owner_answer': 'We regret we did not achieve your expectations during your last stay at the resort, Manohar. Should we have another chance to welcome you, we will do the utmost to make your stay memorable in every moment.',
#    'owner_answer_timestamp': '5 years ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/cWxe2A9bdM98hc246',
#    'review_rating': '1/5',
#    'review_timestamp': '5 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '1',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNadjRDbXJ3RRAB',
#    'author_link': 'https://www.google.com/maps/contrib/110289609330348058319/reviews?hl=en',
#    'author_title': 'WidnesRoseGrower',
#    'author_id': '110289609330348058319',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjV_C1vXw-ZAST_Ggz3soMZOYTMswgn5MFmwAXbHl1IJyg=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': 'Fantastic hotel and staff are excellent',
#    'owner_answer': "Thank you for your fantastic feedback! We're thrilled to hear that you had a great experience at our hotel and that you found our staff to be excellent. Providing exceptional service and a memorable stay is always our goal, and your kind words are greatly appreciated. We look forward to welcoming you back in the future!",
#    'owner_answer_timestamp': '2 weeks ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/4rsL7cS6sPjHPggPA',
#    'review_rating': '5/5',
#    'review_timestamp': '3 weeks ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURRc1lfSjF3RRAB',
#    'author_link': 'https://www.google.com/maps/contrib/109485220525678925764/reviews?hl=en',
#    'author_title': 'LP Ohms',
#    'author_id': '109485220525678925764',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjXyY3TA3UXHO70zy0Vy2AIkZvuGDaGFf1YUUK7tZ-DXh4Nn=w36-h36-p-rp-mo-ba4-br100',
#    'review_text': 'Stunning location and excellent modern friendly 5 star hotel. Rooms very modern, clean and all with lovely views. Great choice for couples and families. Tucked away in the south with A1 motorway links it was a breeze to transfer in our rental car.',
#    'owner_answer': 'Thank you very much for sharing such a positive review on our modern and well-appointed facilities in Mogan, Liam. We are pleased to know you consider our property a great choice for couples and families and we look forward to your next stay. Kind regards',
#    'owner_answer_timestamp': '5 years ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/ANV1v3smudixKVx37',
#    'review_rating': '5/5',
#    'review_timestamp': '5 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '1',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURBb2MtMzRRRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/116167544258082887549/reviews?hl=en',
#    'author_title': 'Alan Harris',
#    'author_id': '116167544258082887549',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocJVxUSp2d7bMxNcvY58HyZ_8ThIGpDIHQZ2NaKi5Y4C=w36-h36-p-rp-mo-br100',
#    'review_text': "Very clean hotel, there are people everywhere working away.\nThe staff are very friendly and literally can't do enough for you.\nLarge selection of food available at meal times. Fish was delicious!!!\nThe team doing the pool/outdoor areas activities were great. From aqua gym which was fun to water polo in the pool. And football, archery, volleyball and rock climbing all on site.\nThere is a quiet area with massive sunbathing and pool area. A gym. A full size tennis court. Pool tables and table tennis table which the kids loved!!\nThere was evening entertainment which to be honest we didn't really see as we were too tired, but it was not loud and couldn't here it in our room.\nWe were half board but you are able to switch your evening meal to lunch, which then enabled us to walk down to the port (10 mins) and have food there. The restaurants in the actual port area are very good, again the fish is very good!!\nThere is also a supermarket about 5 minutes walk away which we used to get water and snacks (was cheaper) and there are some clothes/perfume/souvenir shops.\nWe'd hired a car and travelled off the beaten track right up into the hills which are beautiful. Lots of little taverns and friendly people.\n\nThere is still a lot to say and do but I would recommend this place to anyone. This is the only review I've ever done of a hotel so I must be impressed!!!\nOh, and the waterpark is not far away, if you go buy some water shoes there cheaper than at the market), and its worth investing in the 'fast pass' arm band, as some of the rides had quite a queue and we literally walked straight to the front meaning we got lots more turns on all the rides instead of being stood in a queue. And take a picnic, because we only bought 2 diet cokes and that was 10 Euros!!!!! God knows how much the food was!!!\n\nGreat hotel, great holiday, great people!!! Nothing else to say!!!!",
#    'owner_answer': 'Dear Alan, thank you for such a fantastic review on Google and in particular for praising our staff. We are so happy to read about your memorable holiday experience with us and appreciate all positive highlights you mention. We hope to count on your next visit soon! Kindest regards',
#    'owner_answer_timestamp': '5 years ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/iK91CbHtnAgaLg358',
#    'review_rating': '5/5',
#    'review_timestamp': '5 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURTbGJUQXlRRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/103267941338522189606/reviews?hl=en',
#    'author_title': "Kyla P'an",
#    'author_id': '103267941338522189606',
#    'author_image': 'https://lh3.googleusercontent.com/a-/ALV-UjWoo-7wDp2MicNwetDrGAi91rGbMsxNdNEh7H1XPBjs2Q=w36-h36-p-rp-mo-ba3-br100',
#    'review_text': 'My family planned a last-minute holiday escape during COVID and we couldn’t have been more delighted by how safe, clean and fun the resort was. Our children were able to be around other children, there were lots of activities to do (padel, tennis, basketball, soccer, swimming, spa) and the food was very good. It almost felt like “normal times.”',
#    'owner_answer': "Thank you for your comment. We are very happy to know you and your family totally enjoyed your stay with us. We hope to welcome you back in a near future. Don't hesitate to contact us for any assistance.",
#    'owner_answer_timestamp': '2 years ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/kVzZ8tVng7yprzPL7',
#    'review_rating': '5/5',
#    'review_timestamp': '2 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '0',
#    'review_img_url': []},
#   {'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUR3eTlYbzBRRRAB',
#    'author_link': 'https://www.google.com/maps/contrib/111372212418140117126/reviews?hl=en',
#    'author_title': 'feher barna',
#    'author_id': '111372212418140117126',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocK62LuICZy1tBi2HRK0Q7yC5qU6QSdwS_2Gw5ruqflx=w36-h36-p-rp-mo-br100',
#    'review_text': "I've been to 5 star hotels and surely its not one of them.The staff is nice but their knowledge of english can not be accepted in a 5star hotel!! Inflatables are not allowed in the pool so avoid with kids.Its okay to pay an extra for the spa, but it should be a daily fee not for 3 hours.Service is average but very slow, bar and room both. I still dont regret that I've come here but it became an experience to avoid and warn people to not to pick this place.",
#    'owner_answer': 'Dear Feher Barna,\nThank you very much for your comments and rating. We regret that we were unable to exceed your expectations during your stay. Rest assured we will forward your comments to all the departments concerned to review and action. We hope to have another opportunity to provide you with 5 star service.\nBest regards.',
#    'owner_answer_timestamp': '4 years ago',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/KpFTaq4ga8ZwuhdD6',
#    'review_rating': '1/5',
#    'review_timestamp': '4 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '1',
#    'review_img_url': []},
#   {'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN3OXByWkl3EAE',
#    'author_link': 'https://www.google.com/maps/contrib/103318128068989808836/reviews?hl=en',
#    'author_title': 'Susanne Simons',
#    'author_id': '103318128068989808836',
#    'author_image': 'https://lh3.googleusercontent.com/a/ACg8ocJLVxkpHdHW6Uvo9T_dlcSFB46d9f9jQqM9P3Jz-vEV=w36-h36-p-rp-mo-br100',
#    'review_text': 'lovely hotel , spacious , airy relaxing. Lovely to have a separate quiet area around one of the pools. The rooms are very nice and quiet. I do think the hotel will need to work a bit harder to keep their 5 star rating though. We have over the years stayed in a lot of five star hotels and there are a few things which could cause trouble. when we arrived it was very calm and lovely but it soon became extremely busy and i feel the staff is not really coping. Breakfast buffe very nice but very crowded and long queues for for example pancakes. No breadrolls for breakfast which meant half cut bits of bread lying around. Sticky serving spoons which frankly is unhygienic.\nBoth my husband and I had a massage in the spa which was nice but therapist did not know a word of english? It was the same with some of the restaurant staff and cleaning staff. If you pay a lot to stay in a five star hotel you would expect the staff to know basic english.Some reviews regarding the cleanliness are true, the rooms never really smelt freshly cleaned.  The hotel still deserves a five star rating since all of the above comments are easy to deal with.\nSusanne and family',
#    'owner_answer': '',
#    'owner_answer_timestamp': '',
#    'owner_answer_timestamp_datetime_utc': None,
#    'review_link': 'https://maps.app.goo.gl/gUeLFUGQRBq3ZHHTA',
#    'review_rating': '5/5',
#    'review_timestamp': '6 years ago',
#    'review_datetime_utc': None,
#    'review_likes': '1',
#    'review_img_url': []}]}

# %%
with open("sample.json", "w") as file:
    json.dump(results, file, indent=4)
